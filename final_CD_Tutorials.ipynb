# %% [markdown]
# # <font color=purple> **Music Popularity Across Platforms:** </font>
# ## <font color=#1ed760.> United States' Spotify Charts vs. Billboard Hot 100
#  </font>

# %% [markdown]
# ## **Part 1: Introduction**
# Our idea for this project arose when the topic of 'Spotify Wrapped' came up in one of our classes, leading us to explore how Spotify and other popular music streaming platforms over the years have challenged traditional or mainstream popularity metrics within the music industry. While brainstorming research questions, we agreed that it would be beneficial to collect data from similar sources: in this case, both Spotify charts and the Billboard Hot 100 display “top songs," but the platforms are different enough to isolate any distinctions that might exist between the two.
#
# In 2018, The Washington Post also noted that a shift in the charts had occured, with Billboard being producing more traditonal charts as opposed to how streaming platforms look at musical success. Whereas “Billboard’s charts used to be the barometer for music success,” the Washington Post questioned if this had become “meaningless in the streaming age?” ([Andrews, 2018](https://www.washingtonpost.com/news/arts-and-entertainment/wp/2018/07/05/billboards-charts-used-to-be-our-barometer-for-music-success-are-they-meaningless-in-the-streaming-age/)). The article notes that “since their inception in 1958, the Billboard charts served a window to pop music history. Along with statistics collected by RIAA and Nielsen, they offer a road map of what tunes, musicians and genres Americans found interesting enough to consume en masse” even in modern times ([Andrews, 2018](https://www.washingtonpost.com/news/arts-and-entertainment/wp/2018/07/05/billboards-charts-used-to-be-our-barometer-for-music-success-are-they-meaningless-in-the-streaming-age/)). Trying to “stay in front of the game” Billboard constantly reconsiders how they should respond to up and coming technologies and in 2012 they already added streaming as a metric in their chart. To summarize, “the company is always considering what a song download is worth, what the difference is between a stream and a radio play, etc.” ([Andrews, 2018](https://www.washingtonpost.com/news/arts-and-entertainment/wp/2018/07/05/billboards-charts-used-to-be-our-barometer-for-music-success-are-they-meaningless-in-the-streaming-age/)).

# %% [markdown]
# ![Most-streamed-vs-most-spinned-artists.jpg](attachment:85046e33-fb5d-4a20-89aa-b5dc37a5d547.jpg)
#
# <font color=#1ed760.> *Hypebot based its article on a study done by analytics platform Viberate, which suggests "that while streaming creates hype, radio is still better at driving long-term engagement" (quote from [Hypebot](https://www.hypebot.com/hypebot/2021/08/streaming-creates-hype-but-radio-still-drives-engagement-says-a-new-study.html)). You can access the full report from Viberate [here](https://resources.viberate.com/streaming-vs-radio-airplay). Their research for example discovered that streaming platforms such as Spotify prefer more 'junior' artists, meaning artists with shorter careers (under fifteen years), whilst radio is more accommodating to well-established musicians.* </font>

# %% [markdown]
# While one could say that both Spotify and Billboard charts display popular music, Spotify’s chart formulation is algorithmic, concerning mostly streaming but also shares, number of listeners, including new ones, and even rates of saving songs to playlists or skipping ([Charts, n.d.](https://support.spotify.com/us/artists/article/charts/)), while the Billboard Hot 100 charts are informed by several factors, including sales (physical and digital), radio airplay, digital downloads, and online streaming ([How Do Billboard Charts Work?, 2023](https://inside-the-industry.com/2023/04/21/how-do-billboard-charts-work-the-hot-100-explained/)). Spotify’s chart formulation is much more modern and based on displayed streams in this sense, while the Billboard Hot 100 uses more traditional processes and metrics. According to Billboard’s senior vice president of charts and data development Silvio Pietroluongo, “streaming changed the actual manner in which we listen to music . . . When streaming started, the idea was people would pick the tracks they wanted to hear, but now they’re being fed songs like a jukebox,’” leading to a constant reevaluation of how Billboard should be scoring song popularity to reflect the consumer's behavior in an accurate way ([Andrews, 2018](https://www.washingtonpost.com/news/arts-and-entertainment/wp/2018/07/05/billboards-charts-used-to-be-our-barometer-for-music-success-are-they-meaningless-in-the-streaming-age/)). This shows that Billboard has responded to the changes that occurred in the streaming age, but not without careful consideration.

# %% [markdown]
# ### Goal of the Project
#
# Music charts may hold valuable information that lies beyond what is first recognizable. The overall popularity of songs, artists, and genres may even reflect societal occurrences and their subsequent effects on a population, which can be seen in the study "Unemployment Rate Predicts Anger in Popular Music Lyrics: Evidence From Top 10 Songs in the United States and Germany From 1980 to 2017" by [Qiu, et al (2021)](https://doi.org/10.1037/ppm0000282). The arts, including music, hold important information about the psychological changes that occur alongside societal occurrences. While there has been much documentation about how historical occurrences have given way to the rise of popular genres and artists (i.e. social injustice to hip hop, post-war conservatism to Elvis' dance style), it is still crucial to examine consumer behavior, as it can lead to even more revelations.
#
# Our project aims to highlight differences between two sources of tracking music popularity using different metrics of consumer behavior, providing a useful roadmap for a number of research projects for which this data collection process may be useful. Comparing traditional and modern music popularity metrics may bolster the data's usefulness, as there are significant differences in the demographics of consumers measured by Spotify and the Billboard Hot 100.

# %% [markdown]
# ### Methodology
# So, how does this streaming and the platforms that emerged with it, lead to differences in music consumption? Both organizations use different barometers to account for their weekly charts, and in light of this project, this led us to ask the research question: <font color=purple> **How does music popularity differ across the United States’ Spotify Charts and the Billboard Hot 100?** </font> As the Billboard Hot 100 is the music industry’s standard record chart in the United States, we decided to collect the Spotify charts data, focused on the United States as well, instead of globally. This then makes for a more equal comparative analysis than if we were to compare the Billboard charts to a global Spotify chart, enabling us to compare the platforms, instead of the difference between U.S. listening behavior vs that of the ‘world’. There could be many reasons why differences might exist, including the differing metrics just mentioned, the average ages of those who stream music over a digital platform like Spotify versus those who frequently listen to music over the radio or purchase it, or which charts/platforms artists choose to promote, to name a few factors. This research question opens the door for illuminating data collection. We have collected data from Spotify’s Weekly Top 200 charts throughout 2021 focused on the region ‘United States’ as well as the Billboard Hot 100 charts in 2021.

# %% [markdown]
# <div class="alert-success">
#
# **Tips for members working on this:**
#
# <ol>
#   <li>Please use this Jupyter Notebook in the folder we sent.</li>
#   <p>The folder contains all the dataset you need with the filenames used in this Jupyter Notebook.</p>
#   <li>You don't have to run the code of part 2.1 because it's for generating the dataset of Spotify. </li>
#     <p> The  Spotify dataset is already in the folder. You can directly run it in part 2.2.</p>
# </ol>
#     </div>

# %% [markdown]
# ## **Part 2: Tutorial**

# %% [markdown]
# <div class="alert-info">
#     <h2><strong>Step 1. Collecting data</strong></h2>
# </div>

# %% [markdown]
# To answer our research question, we need to collect data on the top songs in USA shown on Spotify and the Billboard Top 100, including information surrounding the artist's name, song title, place in the top 100, and the number of weeks the song has spent on a music chart.

# %% [markdown]
#  <div class="alert-info">
#     <h3><strong>2.1.Create a Dataset from Weekly Spotify Charts</strong></h3>
# </div>

# %% [markdown]
# 1) Download the weekly charts

# %% [markdown]
# To compile a comprehensive dataset for our analysis, we downloaded top 200 weekly charts spanning all 52 weeks of 2021 from the Spotify Charts website (https://charts.spotify.com/charts/overview/us), which archives weekly charts from various countries.

# %% [markdown]
# 2) Combine weekly chart data and enrich the dataset

# %%
import os
import pandas as pd

# %% [markdown]
# 3) Define the columns we need for the weekly dataset

# %%
col_weekly = ['rank', 'uri', 'artist_names','track_name',
              'peak_rank', 'previous_rank', 'weeks_on_chart', 'streams', 'date',
              'country']

# %% [markdown]
# 4) Function to Combine Data from Multiple CSV Files, Add New Columns, and Extract Top 100 Songs

# %%
def weekly_concat(directory):
    # Initialize an empty DataFrame with the specified columns
    df = pd.DataFrame(columns=col_weekly)

    for filename in os.listdir(directory):
        f = os.path.join(directory, filename)

        # checking if it is a file
        if os.path.isfile(f):
            # Read the first 100 rows from each CSV file
            df_week = pd.read_csv(f, nrows=100)
            # Extract the date from the filename
            date = f[-14:-4]
            # Add 'date' and 'country' columns to the DataFrame
            df_week['date'] = date
            df_week['country'] = country
            df = pd.concat([df, df_week], ignore_index=True) 

    df.to_csv('Spotify_2021_weekly.csv', index=False) 

    return None

# %% [markdown]
# 5) Specify the directory containing CSV files and set the country

# %%
directory = 'Spotify_2021_weekly_charts'
country = 'US'

# %% [markdown]
# 6) Call the function with the specified directory

# %%
weekly_concat('Spotify_2021_weekly_charts')

# %% [markdown]
# **Now, our dataset encompasses the weekly Spotify charts with the following columns: 'rank', 'uri', 'artist_names', 'track_name', 'peak_rank', 'previous_rank', 'weeks_on_chart', 'streams', 'date', and 'country'.**
# <br><br>

# %% [markdown]
#  <div class="alert-info">
#     <h3><strong>2.1.Create a Dataset from Weekly Spotify Charts</strong></h3>
# </div>

# %% [markdown]
# Every week, Billboard releases "The Hot 100" chart of songs that were trending on sales and airplay for that week.
# We discovered a dataset related to Billboard top charts on Kaggle (https://www.kaggle.com/datasets/dhruvildave/billboard-the-hot-100-songs/data). This dataset encompasses all "The Hot 100" charts released since its initiation in 1958.
# For our project, we extracted the data corresponding to the 52 weeks of 2021 in Excel.

# %% [markdown]
# **Then, this dataset includes the weekly Billboard charts with the following columns: 'date', 'rank', 'song', 'artist', 'last-week', 'peak-rank', and 'weeks-on-board'.**
#
# <br>

# %% [markdown]
# <div class="alert-info">
#     <h2><strong>Step 2. Import and Clean the Dataset</strong></h2>
# </div>

# %% [markdown]
# 1) Import the dataset

# %%
spotify_df = pd.read_csv('Spotify_2021_weekly.csv', delimiter=",", encoding = 'utf-8')
billboard_df = pd.read_csv('Billboard_2021_weekly.csv', delimiter=",", encoding = 'utf-8')

# %% [markdown]
# Let's see how they look so far!

# %%
# Show 10 random records from the Spotify table
spotify_df.sample(10)
# Out:
#       rank                                   uri  \
# 3011    12  spotify:track:1IcR6RlgvDczfvoWJSSY2A
# 4371    72  spotify:track:4zm8xZiV5FxJu62EHEvZaT
# 618     19  spotify:track:4RVwu0g32PAqgUiJoXsdF8
# 3680    81  spotify:track:62vpWI1CHwFy7tMIcSStl8
# 3568    69  spotify:track:0RiRZpuVRbi7oqRdSMwhQY
# 2249    50  spotify:track:6M3PsepEj5gyJoIi7Xvr7u
# 677     78  spotify:track:7zjEyeBsaw9gV0jofJLfOM
# 931     32  spotify:track:4Iedi94TIaB2GGb1nMB68v
# 16      17  spotify:track:5lAnYvAIkSDNXqfo7DyFUm
# 2028    29  spotify:track:4eNOLmx8r2IJAVKvBBL1jv
#
#                                 artist_names  \
# 3011                           Andy Williams
# 4371  Bruno Mars, Anderson .Paak, Silk Sonic
# 618                            Billie Eilish
# 3680                                 J. Cole
# 3568                   Post Malone, Swae Lee
# 2249                              The Weeknd
# 677      Young Thug, A$AP Rocky, Post Malone
# 931                                 Lil Baby
# ...

# %%
# Show 10 random records from the Billboard table
billboard_df.sample(10)
# Out:
#          date  rank                    song  \
# 4019  1/30/21    20         Save Your Tears
# 1078  8/28/21    79               Papercuts
# 3222  3/27/21    23                   On Me
# 3462  3/13/21    63      La Noche de Anoche
# 4229  1/16/21    30           Starting Over
# 704   9/18/21     5              Knife Talk
# 765   9/18/21    66              Praise God
# 4131  1/23/21    32        Sand In My Boots
# 1216  8/14/21    17  Heartbreak Anniversary
# 2036  6/19/21    37         Wants And Needs
#
#                                        artist  last-week  peak-rank  \
# 4019                               The Weeknd       21.0         20
# 1078                        Machine Gun Kelly        NaN         79
# 3222                                 Lil Baby       27.0         23
# 3462                      Bad Bunny & Rosalia       58.0         53
# 4229                          Chris Stapleton       35.0         25
# ...

# %% [markdown]
# 2) Rename the columns so the two datasets match

# %%
spotify_df.rename(columns={'artist_names':'artist','track_name':'song','weeks_on_chart':'weeks_on_charts'},inplace= True)
billboard_df.rename(columns={'peak-rank':'peak_rank','weeks-on-board':'weeks_on_charts'},inplace=True)

# %% [markdown]
# 3) Drop columns that won't be analysed

# %%
spotify_df.drop(columns=['uri','country','source','previous_rank'],axis=1, inplace=True)
billboard_df.drop(columns=['last-week'],axis=1, inplace=True)

# %% [markdown]
# 4) Change the order of the columns

# %%
list_spotify = ['song','artist','date','rank','weeks_on_charts','peak_rank','streams']
list_billboard = ['song','artist','date','rank','weeks_on_charts','peak_rank']

# %%
#Assign dataframes
spotify_df = spotify_df[list_spotify]
billboard_df = billboard_df[list_billboard]

# %%
#Show the first 10 records of the Spotify table
spotify_df.head(10)
# Out:
#                                 song                        artist  \
# 0          STAY (with Justin Bieber)  The Kid LAROI, Justin Bieber
# 1  INDUSTRY BABY (feat. Jack Harlow)        Lil Nas X, Jack Harlow
# 2                           good 4 u                Olivia Rodrigo
# 3                       Need to Know                      Doja Cat
# 4                  Happier Than Ever                 Billie Eilish
# 5           Kiss Me More (feat. SZA)                 Doja Cat, SZA
# 6                         Bad Habits                    Ed Sheeran
# 7                               2055                 Sleepy Hallow
# 8                         Heat Waves                 Glass Animals
# 9     MONTERO (Call Me By Your Name)                     Lil Nas X
#
#          date  rank  weeks_on_charts  peak_rank   streams
# 0  2021-08-26     1                7          1  13698566
# 1  2021-08-26     2                5          1  11031868
# ...

# %%
#Show the first 10 records of the Billboard table
billboard_df.head(10)
# Out:
#             song                               artist     date  rank  \
# 0     Easy On Me                                Adele  11/6/21     1
# 1           Stay        The Kid LAROI & Justin Bieber  11/6/21     2
# 2  Industry Baby              Lil Nas X & Jack Harlow  11/6/21     3
# 3     Fancy Like                         Walker Hayes  11/6/21     4
# 4     Bad Habits                           Ed Sheeran  11/6/21     5
# 5     Way 2 Sexy  Drake Featuring Future & Young Thug  11/6/21     6
# 6        Shivers                           Ed Sheeran  11/6/21     7
# 7       Good 4 U                       Olivia Rodrigo  11/6/21     8
# 8   Need To Know                             Doja Cat  11/6/21     9
# 9     Levitating                             Dua Lipa  11/6/21    10
#
#    weeks_on_charts  peak_rank
# 0                3          1
# 1               16          1
# 2               14          1
# 3               19          3
# 4               18          2
# ...

# %% [markdown]
# <div class="alert-info">
#     <h2><strong>Step 3. Data exploration</strong></h2>
# </div>
#
# <br>
# Now that we have our two datasets, it's time to explore!
# <br>
# Let's see what the most popular songs are on Billboard and on Spotify. However, this dataset offers us several measures of popularity. The first way would be to measure by rank, so let's sort the dataset and have a look.

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>3.1 Sorting dataframes</strong></h3>
# </div>
#
# We can create sorted dataframe using the 'sort_values' method.

# %%
billboard_rank_sorted = billboard_df.sort_values(by=['rank'], ascending = True)
spotify_rank_sorted = spotify_df.sort_values(by=['rank'], ascending = True)

# %%
billboard_rank_sorted.head(10)
# Out:
#                      song                         artist     date  rank  \
# 0              Easy On Me                          Adele  11/6/21     1
# 3500      Drivers License                 Olivia Rodrigo   3/6/21     1
# 2800              Rapstar                         Polo G  4/24/21     1
# 1500  Permission To Dance                            BTS  7/24/21     1
# 1000                 Stay  The Kid LAROI & Justin Bieber  8/28/21     1
# 4100      Drivers License                 Olivia Rodrigo  1/23/21     1
# 2500      Save Your Tears     The Weeknd & Ariana Grande  5/15/21     1
# 1200                 Stay  The Kid LAROI & Justin Bieber  8/14/21     1
# 3300          What's Next                          Drake  3/20/21     1
# 2000               Butter                            BTS  6/19/21     1
#
#       weeks_on_charts  peak_rank
# 0                   3          1
# 3500                7          1
# 2800                1          1
# 1500                1          1
# ...

# %%
spotify_rank_sorted.head(10)
# Out:
#                                                    song  \
# 0                             STAY (with Justin Bieber)
# 3900                                           good 4 u
# 1100                                          Good Days
# 4000                                           good 4 u
# 1000                                            RAPSTAR
# 4100                          STAY (with Justin Bieber)
# 4200                                        What’s Next
# 900                      MONTERO (Call Me By Your Name)
# 4300  All Too Well (10 Minute Version) (Taylor's Ver...
# 800                                            good 4 u
#
#                             artist        date  rank  weeks_on_charts  \
# 0     The Kid LAROI, Justin Bieber  2021-08-26     1                7
# 3900                Olivia Rodrigo  2021-06-03     1                3
# 1100                           SZA  2021-01-07     1                2
# ...

# %% [markdown]
# As you can see, some of the songs are repeated because they have been number one for more than one week. Let's create a dataframe that only contains the number one songs.

# %%
number1_spotify = spotify_rank_sorted[spotify_rank_sorted['rank'] == 1]
number1_billboard = billboard_rank_sorted[billboard_rank_sorted['rank'] == 1]

# %%
number1_spotify.head()
# Out:
#                            song                        artist        date  \
# 0     STAY (with Justin Bieber)  The Kid LAROI, Justin Bieber  2021-08-26
# 3900                   good 4 u                Olivia Rodrigo  2021-06-03
# 1100                  Good Days                           SZA  2021-01-07
# 4000                   good 4 u                Olivia Rodrigo  2021-06-17
# 1000                    RAPSTAR                        Polo G  2021-04-22
#
#       rank  weeks_on_charts  peak_rank   streams
# 0        1                7          1  13698566
# 3900     1                3          1  24777068
# 1100     1                2          1   6323585
# 4000     1                5          1  17136875
# 1000     1                2          1  14135559

# %%
number1_billboard.head()
# Out:
#                      song                         artist     date  rank  \
# 0              Easy On Me                          Adele  11/6/21     1
# 3500      Drivers License                 Olivia Rodrigo   3/6/21     1
# 2800              Rapstar                         Polo G  4/24/21     1
# 1500  Permission To Dance                            BTS  7/24/21     1
# 1000                 Stay  The Kid LAROI & Justin Bieber  8/28/21     1
#
#       weeks_on_charts  peak_rank
# 0                   3          1
# 3500                7          1
# 2800                1          1
# 1500                1          1
# 1000                6          1

# %% [markdown]
# Now, let's sort by the number of weeks that songs have been on the chart to see this measure of popularity.

# %%
billboard_weeks_sorted = billboard_df.sort_values(by=['weeks_on_charts'], ascending = False)
spotify_weeks_sorted = spotify_df.sort_values(by=['weeks_on_charts'], ascending = False)

# %%
billboard_weeks_sorted.head()
# Out:
#                  song      artist     date  rank  weeks_on_charts  peak_rank
# 919   Blinding Lights  The Weeknd   9/4/21    20               90          1
# 1020  Blinding Lights  The Weeknd  8/28/21    21               89          1
# 1117  Blinding Lights  The Weeknd  8/21/21    18               88          1
# 1215  Blinding Lights  The Weeknd  8/14/21    16               87          1
# 1316  Blinding Lights  The Weeknd   8/7/21    17               86          1

# %%
spotify_weeks_sorted.head()
# Out:
#             song        artist        date  rank  weeks_on_charts  peak_rank  \
# 286   goosebumps  Travis Scott  2021-11-11    87              254          8
# 1888  goosebumps  Travis Scott  2021-05-13    89              228          8
# 2098  goosebumps  Travis Scott  2021-05-06    99              227          8
# 5192  goosebumps  Travis Scott  2021-04-29    93              226          8
# 1094  goosebumps  Travis Scott  2021-04-22    95              225          8
#
#       streams
# 286   1980463
# 1888  2009272
# 2098  1941338
# 5192  1938945
# 1094  1956547

# %% [markdown]
# As you can see, there are multiple data points for one song. In order to clean this up, we can take the first value that contains the highest value for weeks on chart.

# %%
billboard_weeks_sorted = billboard_weeks_sorted.drop_duplicates(subset='song')
spotify_weeks_sorted = spotify_weeks_sorted.drop_duplicates(subset = 'song')

# %%
billboard_weeks_sorted.head(10)
# Out:
#                      song                                             artist  \
# 919       Blinding Lights                                         The Weeknd
# 3423               I Hope               Gabby Barrett Featuring Charlie Puth
# 9              Levitating                                           Dua Lipa
# 1141  My Ex's Best Friend                      Machine Gun Kelly X blackbear
# 3632        Before You Go                                      Lewis Capaldi
# 2527             Go Crazy                           Chris Brown & Young Thug
# 1247                 Mood                       24kGoldn Featuring iann dior
# 3848         Whats Poppin  Jack Harlow Featuring DaBaby, Tory Lanez & Lil...
# 16        Save Your Tears                         The Weeknd & Ariana Grande
# 840     Forever After All                                         Luke Combs
#
#          date  rank  weeks_on_charts  peak_rank
# 919    9/4/21    20               90          1
# ...

# %%
spotify_weeks_sorted.head(10)
# Out:
#                                                song                 artist  \
# 286                                      goosebumps           Travis Scott
# 2375                                 No Role Modelz                J. Cole
# 2396                                   Lucid Dreams             Juice WRLD
# 4286                                 Jocelyn Flores           XXXTENTACION
# 285                          All Girls Are The Same             Juice WRLD
# 2386  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# 4295                       SLOW DANCING IN THE DARK                   Joji
# 4899                                        Robbery             Juice WRLD
# 3577                                   MIDDLE CHILD                J. Cole
# 280                                         Circles            Post Malone
#
#             date  rank  weeks_on_charts  peak_rank  streams
# 286   2021-11-11    87              254          8  1980463
# ...

# %% [markdown]
# What similarities and differences do you notice between songs and the weeks on the chart between the two datasets at first glance?

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>3.2. Descriptive statistics</strong></h3>
# </div>
#
# To get a more general overview of what exists in the data, we can also use the describe() function to explore our data.

# %%
spotify_weeks_sorted.describe()
# Out:
#              rank  weeks_on_charts   peak_rank       streams
# count  770.000000       770.000000  770.000000  7.700000e+02
# mean    71.383117        13.677922   37.374026  2.619487e+06
# std     24.580749        24.905599   28.764690  9.176311e+05
# min      1.000000         1.000000    1.000000  1.783609e+06
# 25%     55.000000         1.000000   12.000000  2.018215e+06
# 50%     79.000000         4.000000   32.000000  2.296956e+06
# 75%     92.000000        17.000000   59.000000  2.838542e+06
# max    100.000000       254.000000  100.000000  8.608916e+06

# %%
billboard_weeks_sorted.describe()
# Out:
#              rank  weeks_on_charts   peak_rank
# count  664.000000       664.000000  664.000000
# mean    69.871988         8.980422   47.295181
# std     24.926804        11.032158   29.736351
# min      1.000000         1.000000    1.000000
# 25%     50.000000         1.000000   20.000000
# 50%     77.000000         4.000000   48.000000
# 75%     91.000000        15.000000   71.250000
# max    100.000000        90.000000  100.000000

# %% [markdown]
# For the Billboard top songs, it seems that songs are on the charts for less weeks at a time, while for Spotify a song will be more popular longer. The Billboard mean for weeks a song is on the chart is 8.98, whereas on spotify it is 13.68 (about 4 weeks longer!). Additionally, the Billboard range is from 1 week to 90 weeks and the Spotify range for weeks on chart is up to 254 weeks.

# %% [markdown]
# <div class="alert-info">
#     <h2><strong>Step 4. Visualization</strong></h2>
# </div>

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>4.1 Differences on Artist Preference</strong></h3>
# </div>
#
# To get a more general overview of what exists in the data, we will visualize differences in artist preferences on Spotify and Billboard.

# %%
pip install pandas matplotlib scikit-learn
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for nicer plots and make the colours more readable for colorblind people that may read the tutorial
sns.set(style="whitegrid")
sns.set_palette("colorblind", n_colors=10)

# %% [markdown]
# #### Preprocess data

# %%
# Convert 'date' column to datetime
spotify_df['date'] = pd.to_datetime(spotify_df['date'])
billboard_df['date'] = pd.to_datetime(billboard_df['date'])

# Aggregate for dataset
spotify_artist_stats = spotify_df.groupby('artist').agg({'streams': 'sum', 'rank': 'mean'})
billboard_artist_stats = billboard_df.groupby('artist').agg({'weeks_on_charts': 'count', 'rank': 'mean'})

# Merge the datasets
combined_df = pd.merge(spotify_artist_stats, billboard_artist_stats, 
                       left_index=True, right_index=True)  # Adjust left_on and right_on if necessary

# Rename columns for clarity
combined_df.rename(columns={'rank_x': 'Spotify_Avg_Rank', 'rank_y': 'Billboard_Avg_Rank',
                            'streams': 'Spotify_Total_Streams', 
                            'weeks_on_charts': 'Billboard_Total_Weeks'}, inplace=True)
# Out:
# /var/folders/wh/znrp92p10x5228lvxktxwk000000gn/T/ipykernel_39639/558260110.py:3: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>A) Create a Scatter Plot to Compare Average Ranks on Spotify and Billboard</strong></h3>
# </div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
# Assuming 'Total_Streams' is a column in your dataframe that represents the total number of streams for a song
point_sizes = combined_df['Spotify_Total_Streams'] / 1000  # Scale down for better visualization
sns.scatterplot(data=combined_df, x='Spotify_Avg_Rank', y='Billboard_Avg_Rank', size=point_sizes, legend=False, alpha=0.7)
plt.title('Average Rank Comparison: Spotify vs Billboard')
plt.xlabel('Spotify Average Rank')
plt.ylabel('Billboard Average Rank')
plt.gca().invert_xaxis() # Inverts the X-axis for better visualization

sns.regplot(data=combined_df, x='Spotify_Avg_Rank', y='Billboard_Avg_Rank', scatter=False, color='red')
plt.show()

# %% [markdown]
# In the scatter plot, each point represents an artist. The position of the point is determined by the artist's average rank on Spotify and Billboard. Points closer to the bottom right corner indicate artists who have a high average rank (lower numerical value, which is better) on both platforms. From the scatter plot, we can observe that there is a spread of points across the plot, but there doesn't seem to be a clear, strong correlation between Spotify and Billboard rankings. While there are a few points towards the bottom right, suggesting some artists rank highly on both platforms, the majority of the points are scattered, indicating variability in how artists are ranked between Spotify and Billboard. To discover the artists and their performace on both platforms, we can make another, a more detailed plot in the hext section.

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>B) Create an Interactive Scatter Plot Using Plotly: Top artists' performance in Spotify and Billboard charts</strong></h3>
# </div>

# %%
import plotly.express as px

# Ensure you have Plotly Express installed: pip install plotly
# Create the scatter plot
fig = px.scatter(
    combined_df.reset_index(),  # Reset the index to turn the 'artist' index into a column
    x='Spotify_Avg_Rank', 
    y='Billboard_Avg_Rank', 
    size='Spotify_Total_Streams',  # Size of the bubbles
    color='Billboard_Total_Weeks',  # Color of bubbles can represent another dimension, like total weeks
    hover_name='artist',  # Shows the artist name when hovering over the point
    title='Top artists performance in Spotify and Billboard charts'
)

# Update the layout of the plot for better readability
fig.update_layout(
    xaxis_title='Spotify Average Rank',
    yaxis_title='Billboard Average Rank',
    xaxis_autorange='reversed',  # Reverses the X-axis
    yaxis_autorange='reversed',  # Reverses the Y-axis
)

# Show the plot
fig.show()

# %% [markdown]
# <div class="alert-warning">
# Note: This screenshot was added for a preview in GitHub. Since the plot is interactive, it would not show on GitHub. However, as soon as you download the repository, you can interact with the actual plot.
# </div>

# %% [markdown]
# ![interactive_plot.png](attachment:dfba703a-b2ce-4ddd-8c37-48d4266aafd4.png)The size of the point reflects the total streams of the artist on Spotify. Hovering over a point shows additional information like the artist's name, total streams on Spotify, and total weeks on Billboard. The position of the artist names on the plot indicates their relative ranks on both platforms. For instance, artists like Brenda Lee and Glass Animals, which appear closer to the top right corner, likely have a high average rank (better performance) on both Spotify and Billboard. Some artist with a higher Billboard rank but a lower Spotify rank might be indicative of a release that is popular in sales or radio play but not as much on streaming platforms, e.g. Mariah Carey or the Weeknd.

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>C) Create Comparative Histograms for Spotify and Billboard Average Ranks: Artist ranking trends</strong></h3>
# </div>

# %%
# Create comparative histograms to show the distribution of ranks for artists on Spotify and Billboard

plt.figure(figsize=(12, 6))
sns.histplot(combined_df['Spotify_Avg_Rank'], color="#298c8c", label="Spotify Avg Rank", kde=True)
sns.histplot(combined_df['Billboard_Avg_Rank'], color="#800074", label="Billboard Avg Rank", kde=True)
plt.title('Distribution of Average Ranks on Spotify and Billboard')
plt.xlabel('Average Rank')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# The highest purple bar (Billboard) is closer to the left side of the chart, which means that on Billboard, more artists tend to have lower ranks (and lower ranks are better – think of it as being closer to number 1).
#
# The highest turquoise (Spotify) is a bit more to the right than the highest blue bar. This suggests that artists on the Spotify chart tend to have slightly higher ranks on average (which means not as close to number 1 compared to Billboard).
#
# **Popularity Concentration:** There seems to be a larger cluster of popular artists on Sporify that are getting the best (lowest) ranks. On Billboard, the artists' ranks are spread out a bit more.
#
# **Chance of Ranking:** Artists on Billboard might have a better chance of getting a better rank because the purple bars are taller on the lower end (left side) than the turquoise bars.
#
# **Variety of Artists:** It could be that Spotify has a broader variety of artists that get into the lower ranks, while Billboard might have a smaller group of artists that stay in those top spots for longer.

# %% [markdown]
# <div class="alert-info">
#     <h3><strong>D) Create Bar Charts to Compare Top Artists on Spotify and Billboard</strong></h3>
# </div>

# %%
# Determine the top artists on each platform by the number of songs they have.

# Spotify Top Artists
top_artists_spotify = spotify_df['artist'].value_counts().head(10)
# Billboard Top Artists
top_artists_billboard = billboard_df['artist'].value_counts().head(10)
# Create bar charts for visual comparison for Top Performing Artists, compare the number of songs by the top artists on each chart.
# Set the size of the overall figure
plt.figure(figsize=(15, 6))

# Bar chart for Spotify
plt.subplot(1, 2, 1)
sns.barplot(x=top_artists_spotify, y=top_artists_spotify.index)
plt.title('Top Artists on Spotify (2021)')
plt.xlabel('Number of Songs')
plt.ylabel('Artist')

# Bar chart for Billboard
plt.subplot(1, 2, 2)
sns.barplot(x=top_artists_billboard, y=top_artists_billboard.index)
plt.title('Top Artists on Billboard (2021)')
plt.xlabel('Number of Songs')
plt.ylabel('Artist')

# Adjust layout for better visibility
plt.tight_layout()

# Display the charts
plt.show()

# %% [markdown]
# From the output, we can see that Olivia Rodrigo is the top artist on both Spotify and Billboard based on the number of songs listed in 2021. The fact that some artists like Morgan Wallen, Doja Cat, The Weeknd, and Kanye West appear on both lists, suggests they were popular on both platforms. Artists like Taylor Swift and Polo G appear in the top 10 for Spotify but not for Billboard, while Luke Combs, Ariana Grande, Moneybagg Yo, and Drake appear in the top 10 for Billboard but not for Spotify. This indicates that there may be variations in audience preferences or how songs are promoted and consumed on each platform.

# %%
# Import Libraries
import matplotlib.pyplot as plt

# Create a list of unique artists from both charts
all_artists = list(set(list(top_artists_spotify.keys()) + list(top_artists_billboard.keys())))

# Initialize variables for plotting
positions = range(len(all_artists))
bottom_spotify = [0] * len(all_artists)
bottom_billboard = [0] * len(all_artists)

# Create a figure and axis
plt.figure(figsize=(12, 6))

# Plot Spotify data
plt.bar(positions, [top_artists_spotify.get(artist, 0) for artist in all_artists],
        color='#298c8c', label='Spotify', alpha=0.6)

# Plot Billboard data on top of Spotify data
plt.bar(positions, [top_artists_billboard.get(artist, 0) for artist in all_artists],
        bottom=bottom_spotify, color='#800074', label='Billboard', alpha=0.6)

# Update bottom values for the next set of bars
bottom_spotify = [bottom_spotify[i] + top_artists_spotify.get(artist, 0) for i, artist in enumerate(all_artists)]
bottom_billboard = [bottom_billboard[i] + top_artists_billboard.get(artist, 0) for i, artist in enumerate(all_artists)]

# Set labels and legend
plt.xlabel('Artists')
plt.ylabel('Number of Songs')
plt.title('Top Performing Artists')
plt.xticks(positions, all_artists, rotation='vertical')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# This combined popularity metric as a combination of what we saw in the previous visualization, and it provides a more holistic view of an artist's popularity than looking at either Spotify streams or Billboard chart presence alone. The combined popularity scores seem to have a quick drop-off after the first few artists, indicating a significant difference in combined popularity between the top-ranked artists and those ranked lower. Olivia Rodrigo's score is notably higher than the others, suggesting her dominance across both streaming and chart presence during the measured period.

# %% [markdown]
# <div class="alert-success">
#  Tips for Effective Visualization: Try to adjust the sizes parameter to ensure that bubbles are distinct and visually informative, and adjust the alpha parameter to make the chart more readable, especially if bubbles overlap.</div>

# %%
# !pip install matplotlib-venn
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %% [markdown]
# <div class="alert-info" >
#     <h3><strong>E) Create a Heatmap of Artist Presence on Spotify and Billboard Charts</strong></h3>
# </div>

# %%
# Rename rank columns for clarity
spotify_df.rename(columns={'rank': 'rank_spotify'}, inplace=True)
billboard_df.rename(columns={'rank': 'rank_billboard'}, inplace=True)

# Print column names to verify the changes
print("Spotify DataFrame columns:", spotify_df.columns)
print("Billboard DataFrame columns:", billboard_df.columns)

# Merge datasets on artist and song
combined_df = pd.merge(spotify_df, billboard_df, on=['artist', 'song'], how='outer')

# Print column names of the combined DataFrame
print("Combined DataFrame columns:", combined_df.columns)
# Out:
# Spotify DataFrame columns: Index(['song', 'artist', 'date', 'rank_spotify', 'weeks_on_charts',
#        'peak_rank', 'streams'],
#       dtype='object')
# Billboard DataFrame columns: Index(['song', 'artist', 'date', 'rank_billboard', 'weeks_on_charts',
#        'peak_rank'],
#       dtype='object')
# Combined DataFrame columns: Index(['song', 'artist', 'date_x', 'rank_spotify', 'weeks_on_charts_x',
#        'peak_rank_x', 'streams', 'date_y', 'rank_billboard',
#        'weeks_on_charts_y', 'peak_rank_y'],
#       dtype='object')

# %%
# Filter out rows where either 'rank_spotify' or 'rank_billboard' is NaN, ensure we only analyze artists who have rankings on both platforms
filtered_df = combined_df.dropna(subset=['rank_spotify', 'rank_billboard'])

# Create a pivot table with the filtered data
artist_pivot = filtered_df.pivot_table(index='artist', 
                                       values=['rank_spotify', 'rank_billboard'], 
                                       aggfunc='mean')

# Fill any NaN values, if necessary (should be minimal or none after filtering)
artist_pivot.fillna(0, inplace=True)

# Plot the heatmap with an adjusted figure size
plt.figure(figsize=(10, 20))  # Adjust the size as needed based on the number of artists
sns.heatmap(artist_pivot, annot=True, cmap='viridis')
plt.title('Heatmap of Artist Presence on Both Spotify and Billboard Charts')
plt.xlabel('Chart')
plt.ylabel('Artist')
plt.show()

# %% [markdown]
# The overall distribution of colors across the heatmap gives a visual representation of how artists compare overall on the two platforms. The intensity of the color correlates with the rank's value. Darker purple shades indicate a higher position (closer to 1), and brighter green/yellow ones suggest a lower position (further away from 1). By comparing the color intensities for each artist across both platforms, we can determine where an artist is more popular or has a better ranking. For instance, some artists like Camila Cabello Justin Bieber, Masked Wolf,  have relatively balanced rankings, but some artists, for instance,  Andy Williams and Ariana Grande have a significantly higher ranking on Spotify compared to Billboard.  In addition, Adele has an average rank of 23 on Spotify and 6.4 on Billboard, indicating a better average position on Billboard charts. This visualization can help us undestand whose musice  might be more popular or better promoted on Billboard compared to Spotify (or the other way round).

# %% [markdown]
# <div>
#     <h2><strong>What we can conclude from the visualizations</strong></h2>
# </div>
#
# **Rankings and Popularity:**
# The scatter plot visualizations indicated a varied relationship between artists' average rankings on Spotify versus Billboard, with some artists achieving high ranks on both platforms and others showing disparity. This suggests that while there is some agreement on artist popularity, there are also significant differences that could be attributed to platform-specific audiences and consumption patterns.
#
# **Platform Preferences:**
# The comparative histogram revealed that Spotify tends to have a cluster of artists with lower average ranks, indicating a concentration of popularity among these artists. In contrast, Billboard's distribution suggested a broader spread of artist ranks. This could imply that artists are more evenly ranked on Billboard, or that the platform has a different ranking dynamic.
#
# **Top Artists Analysis:**
# Examining the top artists on each platform highlighted that some artists, like Olivia Rodrigo and Doja Cat, were popular across both Spotify and Billboard. However, there were noticeable differences, with certain artists appearing only on one platform's top list. This underlines the presence of platform-specific preferences and possibly different audience demographics.
#
# **Combined Popularity Metric:**
# By creating a metric that combined Spotify streams and Billboard weeks, we could see a stark difference in the combined popularity between the highest-ranking artists and the rest. Olivia Rodrigo, in particular, again stood out, indicating her cross-platform appeal and dominance in both streaming and chart performance.
#
# **Heatmap Observations:**
# Finally, the heatmap provided a direct comparison of artists' average ranks on both platforms. It showed that some artists have consistent rankings across platforms, while others, such as Ariana Grande and Adele, have more pronounced success on one. Adele, for example, had a notably better average rank on Billboard, which could indicate a stronger appeal or promotional presence there.
#
# In essence, while there is some crossover in artist popularity on Spotify and Billboard, the analyses underscored that each platform has unique trends and artist rankings. These findings can help industry stakeholders, or anyone interested in the topic, understand where artists are gaining traction and how different platforms/charts reflect on varied listener preferences.

# %% [markdown]
# ## **Part 3: Active Learning Exercises**

# %% [markdown]
# We now have the data of top 100 songs in USA throughout 2021 on these two platforms. With these datasets we can explore the trends, popularity, and differences in the music industry. In this part of active learning exercises we want to prompt and answer some possible analysis. Here are three learning exercises.

# %%
# !pip install wordcloud
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# import required library for the exercises
import os
import numpy as np
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert-info" >
#     <h3><strong> Exercises </strong></h3>
# </div>

# %% [markdown]
#  <div>
#     <h3><strong>Q1: Measuring the popularity of different artists on Billboard Hot 100 using WordCloud</strong></h3>
# </div>

# %% [markdown]
# WordCloud is a good tool you can use to visualize the popularity of the artist. But first, you might want to count the frequency of artists appearing in the Billboard chart. Then you can visualize the result by WordCloud.

# %%
#The first thing we want to do is read our Billboard CSV file into a dataframe and assign a variable for the 
#column containing the artists' names.

# Read the file
csv_file_path = ... 

#Create a dataframe
df = ...

#Assign a variable for the column
artist_column = ...

# %% [markdown]
# Great! The next important thing to do is extract the names of the artists and count the frequency of each artist.

# %%
# Extract artist names from the DataFrame
artist_names = ...

# Count the frequency of each artist
artist_counts = ...

# %% [markdown]
# Amazing, we're one step closer to creating our visualization! Now, we can finally create our WordCloud and the frequency chart.

# %%
# Generate a word cloud using the artist frequencies

wordcloud = ...

# Display the word cloud (you can use the plt. commands for this)


# Display the frequency list

# %% [markdown]
# What do you see in this wordcloud? What artists are the most popular on Billboard?

# %% [markdown]
#  <div>
#     <h3>Q2 - data extraction and visualization: How long does a song stay in Top 100 on Spotify? </h3> </div>

# %% [markdown]
# For this exercise, explore how many weeks do songs generally stay on both charts. Provide a bar chart graph of the duration of stay in the chart. Then you can see what songs stayed in the Top 100 for the longest time.

# %% [markdown]
# First, we will need to make the grouping by song and artist. You can have a look at how we did grouping and indexing in the codes for the visuzalizations above.

# %%
# Group by both 'track_name' and 'artist' using the sporify_df (the Spotify dataframe) that we already created in the 
#exploration part of the notebook. You don't need to redefine anything, as it should be already available for you 
#if you run the whole notebook.

weeks_in_top_100 = ... 

# Now sort this dataframe to get the songs with the longest stay

# Reset the index of the sorted DataFrame

# %% [markdown]
# Next we need to import the library for creating the plot.

# %%
# Import the library
import matplotlib.pyplot as plt

# %% [markdown]
# Now you can create a histogram to see the distribution of the weeks that the most popular songs stay in the top 100.

# %%
# Create a histogram
# Your code

# %% [markdown]
# Great job on making the histogram! Now let's create a table to see what songs stayed in the chart the longest.

# %%
# Reset the index so that 'song' and 'artist' are not part of the index

longest_staying_songs = ...

# Convert DataFrame to a string without the index and print it

# %% [markdown]
# <div class="alert-info" >
#     <h3><strong> Potential Solutions</strong></h3>
# </div>

# %% [markdown]
# #### Q1 Solution

# %%
# Read the CSV file into a DataFrame
csv_file_path = 'Billboard_2021_weekly.csv'
df = pd.read_csv(csv_file_path)
artist_column = 'artist'

# Extract artist names from the DataFrame
artist_names = df[artist_column].dropna().astype(str)

# Count the frequency of each artist
artist_counts = artist_names.value_counts()

# Generate a word cloud using the artist frequencies
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(artist_counts)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Don't show axis
plt.show()

# Display the frequency list
print(artist_counts)
# Out:
# artist
# Olivia Rodrigo                                        163
# Morgan Wallen                                          93
# Doja Cat                                               79
# The Weeknd                                             64
# Luke Combs                                             63
#                                                      ...
# Young Thug Featuring Lil Uzi Vert & Yung Kayo           1
# Young Thug Featuring Rowdy Rebel                        1
# Young Thug & Gunna Featuring Lil Baby & YTB Trench      1
# Trippie Redd Featuring SoFaygo                          1
# Taylor Swift Featuring HAIM                             1
# Name: count, Length: 447, dtype: int64

# %% [markdown]
# From the result, we can see that the top 5 artists from Billboard in 2021 is Olivia Rodrigo, Morgan Wallen, Doja Cat, Luke Combs, and the Weeknd.

# %% [markdown]
# #### Q2 Solution on Spotify

# %%
#Group by both 'track_name' and 'artist' using the sporify_df (the Spotify dataframe) that we already created in the 
#exploration part of the notebook. You don't need to redefine anything, as it should be already available for you 
#if you run the whole notebook.

weeks_in_top_100 = spotify_df.groupby(['song', 'artist']).size().reset_index(name='weeks_in_top_100')

# Now sort this dataframe to get the songs with the longest stay
longest_staying_songs = weeks_in_top_100.sort_values(by='weeks_in_top_100', ascending=False).head(10)

# Reset the index of the sorted DataFrame
longest_staying_songs = longest_staying_songs_with_artist.reset_index(drop=True)

# Create the histogram
import matplotlib.pyplot as plt
plt.hist(weeks_in_top_100['weeks_in_top_100'], bins=range(1, weeks_in_top_100['weeks_in_top_100'].max() + 1), edgecolor='black')
plt.title('Distribution of Weeks Songs Stay in Top 100')
plt.xlabel('Weeks in Top 100')
plt.ylabel('Number of Songs')
plt.show()

# Convert DataFrame to a string without the index and print it
print(longest_staying_songs.to_string(index=False))
# Out:
#                                          song                       artist  weeks_in_top_100
#                     Levitating (feat. DaBaby)             Dua Lipa, DaBaby                52
#                               Sweater Weather            The Neighbourhood                52
#                                    Heat Waves                Glass Animals                52
#                               drivers license               Olivia Rodrigo                50
#                               Blinding Lights                   The Weeknd                49
#                                No Role Modelz                      J. Cole                49
#                                     Good Days                          SZA                46
# Sunflower - Spider-Man: Into the Spider-Verse        Post Malone, Swae Lee                46
#                                       Circles                  Post Malone                44
# ...

# %% [markdown]
# The songs that have been in Top 100 on Spotify (US, 2021) for almost the whole year are: Levitating (feat. DaBaby) (52 weeks), Sweater Weather (52 weeks), Heat Waves (52 weeks), drivers license (50 weeks), Blinding Lights (49 weeks).

# %% [markdown]
# #### **Great job, you have finished the tutorial, including all the active learning exercises. Happy data exploring! 😊**

# %% [markdown]
# <div class="alert-info">
#     <h2><strong>References</strong></h2>
# </div>

# %% [markdown]
# - Andrews, T. M. (2021). Analysis | Billboard’s charts used to be our barometer for music success. Are they meaningless in the streaming age? Washington Post. https://www.washingtonpost.com/news/arts-and-entertainment/wp/2018/07/05/billboards-charts-used-to-be-our-barometer-for-music-success-are-they-meaningless-in-the-streaming-age/
# - Charts. (n.d.). Spotify. Retrieved January 16, 2024, from https://support.spotify.com/us/artists/article/charts/
# - Report | Did Streaming Kill the Radio Star? (n.d.). Retrieved January 16, 2024, from https://resources.viberate.com/streaming-vs-radio-airplay
# - Streaming creates hype, but radio still drives engagement says a new study. (2021, August 5). Hypebot. https://www.hypebot.com/hypebot/2021/08/streaming-creates-hype-but-radio-still-drives-engagement-says-a-new-study.html
# -  How Do Billboard Charts Work? (2023).[The Hot 100 Explained]. Inside The Industry. https://inside-the-industry.com/2023/04/21/how-do-billboard-charts-work-the-hot-100-explained/
# - Qiu, Lin, Sarah Hian may Chan, Kenichi Ito, and Joyce Yan ting Sam. "Unemployment Rate Predicts Anger in Popular Music Lyrics: Evidence from Top 10 Songs in the United States and Germany from 1980 to 2017." Psychology of Popular Media 10, no. 2 (2021): 256-66. https://doi.org/10.1037/ppm0000282
